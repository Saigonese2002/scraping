# %%
import pandas as pd

df = pd.read_json('data.json')
df.sample(5)
# Out:
#                                         Name Condition      Price  Location  \
# 304        Mercedes Benz C class C200 - 2019     Xe cũ  899 Triệu    Hà Nội
# 58           Hyundai i10 Grand 1.2 AT - 2020     Xe cũ  365 Triệu    Hà Nội
# 130        Mitsubishi Attrage 1.2 CVT - 2023    Xe mới  465 Triệu    TP HCM
# 418  Mitsubishi Triton Athlete 4x2 AT - 2023    Xe mới  780 Triệu    TP HCM
# 191            Toyota Innova E 2.0 MT - 2023    Xe mới  715 Triệu  Bắc Ninh
#
#                                                   Link  \
# 304  https://bonbanh.com/xe-mercedes_benz-c_class-c...
# 58   https://bonbanh.com/xe-hyundai-i10-grand-1.2-a...
# 130  https://bonbanh.com/xe-mitsubishi-attrage-1.2-...
# 418  https://bonbanh.com/xe-mitsubishi-triton-athle...
# 191  https://bonbanh.com/xe-toyota-innova-e-2.0-mt-...
#
#                                            Description     Car_code  \
# 304   *Xe lắp ráp trong nước, màu đen, máy xăng 1.5...  Mã: 5452057
# ...

# %%
df.to_csv('data.csv', index = False)
